# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.shape
# Out:
# (200, 4)

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
plt.scatter(x['TV'],y,color='c')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.title('TV Sales Graph')
# Out:
# Text(0.5, 1.0, 'TV Sales Graph')

# %%
plt.scatter(x['Radio'],y,color='c')
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.title('Radio Sales Graph')
# Out:
# Text(0.5, 1.0, 'Radio Sales Graph')

# %%
plt.scatter(x['Newspaper'],y,color='c')
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.title('Newspaper Sales Graph')
# Out:
# Text(0.5, 1.0, 'Newspaper Sales Graph')

# %%
#Seaborn
#regplot
#Only for nummerical columns
import seaborn as sns
sns.regplot(x=df['TV'],y=y,color='c')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.regplot(x=df['Radio'],y=y,color='c')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.regplot(x=df['Newspaper'],y=y,color='c')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
#         TV  Radio  Newspaper
# 131  265.2    2.9       43.0
# 96   197.6    3.5        5.9
# 181  218.5    5.4       27.4
# 19   147.3   23.9       19.1
# 153  171.3   39.7       37.7
# ..     ...    ...        ...
# 67   139.3   14.5       10.2
# 192   17.2    4.1       31.6
# 117   76.4    0.8       14.8
# 47   239.9   41.5       18.5
# 172   19.6   20.1       17.0
#
# [140 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 18    69.2   20.5       18.3
# 170   50.0   11.6       18.4
# 107   90.4    0.3       23.2
# 98   289.7   42.3       51.2
# 177  170.2    7.8       35.2
# 182   56.2    5.7       29.7
# 5      8.7   48.9       75.0
# 146  240.1    7.3        8.7
# 12    23.8   35.1       65.9
# 152  197.6   23.3       14.2
# 61   261.3   42.7       54.7
# 125   87.2   11.8       25.9
# 180  156.6    2.6        8.3
# 154  187.8   21.1        9.5
# 80    76.4   26.7       22.3
# 7    120.2   19.6       11.6
# 33   265.6   20.0        0.3
# 130    0.7   39.6        8.7
# 37    74.7   49.4       45.7
# 74   213.4   24.6       13.1
# 183  287.6   43.0       71.8
# 145  140.3    1.9        9.0
# 45   175.1   22.5       31.5
# 159  131.7   18.4       34.6
# 60    53.5    2.0       21.4
# 123  123.1   34.6       12.4
# 179  165.6   10.0       17.6
# 185  205.0   45.1       19.6
# 122  224.0    2.4       15.6
# 44    25.1   25.7       43.3
# 16    67.8   36.6      114.0
# ...

# %%
y_train
# Out:
# 131    17.7
# 96     16.7
# 181    17.2
# 19     14.6
# 153    16.0
#        ...
# 67     13.4
# 192     5.9
# 117     9.4
# 47     23.2
# 172     7.6
# Name: Sales, Length: 140, dtype: float64

# %%
y_test
# Out:
# 18     11.3
# 170     8.4
# 107    12.0
# 98     25.4
# 177    16.7
# 182     8.7
# 5       7.2
# 146    18.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    15.5
# 154    20.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     16.1
# 159    12.9
# 60      8.1
# 123    15.2
# 179    17.6
# 185    22.6
# 122    16.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      17.9
# 83     13.6
# 106     7.2
# 134    10.8
# 66     11.0
# 26     15.0
# 113    20.9
# 168    17.1
# 63     14.0
# 8       4.8
# 75      8.7
# 118    15.9
# 143    10.4
# 71     12.4
# 124    19.7
# 184    17.6
# 97     20.5
# 149    10.1
# 24      9.7
# 30     21.4
# 160    16.4
# 40     16.6
# 56      5.5
# Name: Sales, dtype: float64

# %%
#Model Creation
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([10.68909303,  8.67371102,  9.59969914, 24.99989846, 14.73590568,
#         8.37604918, 10.70350416, 18.37670708,  9.9670026 , 17.87946837,
#        23.52765543, 10.70692059, 13.37566958, 17.10051561, 11.77005197,
#        13.31194616, 21.13395461,  9.10945664, 14.24009701, 18.86885012,
#        25.00670623, 12.42508633, 16.61899482, 13.84289673,  7.80458355,
#        15.13012055, 14.69687153, 20.70140682, 16.9844145 ,  8.94984434,
#        12.59168427, 20.93257626, 21.34337227, 21.89151357,  7.23908022,
#         7.06001103,  9.28335812, 15.6840471 , 13.33894748,  7.28903633,
#        11.05676585,  9.08768206, 15.60592891, 18.21716827, 18.9560652 ,
#        13.47385617,  5.36520991, 10.59696871, 15.66036131, 10.98229096,
#        12.20805533, 20.70970272, 20.70533061, 16.95931925,  9.96622132,
#         9.44413497, 23.60505449, 15.99066008, 18.06706692,  8.25675464])

# %%
print(model.predict([[28,32,37]]))
# Out:
# [9.7901998]
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print('Slope :',list((zip(x,model.coef_))))
# Out:
# Slope : [('TV', np.float64(0.05365016513958255)), ('Radio', np.float64(0.11073062197220998)), ('Newspaper', np.float64(0.002036974576510868))]

# %%
print('Constant :',model.intercept_)
# Out:
# Constant : 4.66924721239252

# %%
df1=pd.DataFrame({'Actual value':y_test,'Predicted value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#      Actual value  Predicted value  Difference
# 18           11.3        10.689093    0.610907
# 170           8.4         8.673711   -0.273711
# 107          12.0         9.599699    2.400301
# 98           25.4        24.999898    0.400102
# 177          16.7        14.735906    1.964094
# 182           8.7         8.376049    0.323951
# 5             7.2        10.703504   -3.503504
# 146          18.2        18.376707   -0.176707
# 12            9.2         9.967003   -0.767003
# 152          16.6        17.879468   -1.279468
# 61           24.2        23.527655    0.672345
# 125          10.6        10.706921   -0.106921
# 180          15.5        13.375670    2.124330
# 154          20.6        17.100516    3.499484
# 80           11.8        11.770052    0.029948
# 7            13.2        13.311946   -0.111946
# 33           17.4        21.133955   -3.733955
# 130           1.6         9.109457   -7.509457
# 37           14.7        14.240097    0.459903
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,root_mean_squared_error,r2_score
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 1.3662313868452756

# %%
MAPE=mean_absolute_percentage_error(y_test,y_pred)
MAPE
# Out:
# 0.17222599691973423

# %%
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 3.938015220480285

# %%
RMSE=root_mean_squared_error(y_test,y_pred)
RMSE
# Out:
# 1.9844433024100954

# %%
score=r2_score(y_test,y_pred)
score
# Out:
# 0.869205273491013
